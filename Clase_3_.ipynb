# %% [markdown]
# <a href="https://colab.research.google.com/github/gutierrezari/PROGCOM---A/blob/main/Clase_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Solucion propuesta por Clan Brillitos
for i in range(1,6)
  estudiante=int(input(f"Ingrese la experiencia del estudiante {1}"))
  #acumulador
  suma=suma+estudiante

  promedio=suma/n

  for i in range (1, n+1):
      estudiante=int(input(f"ingrese la experiencia del estudiante {1}"))
      #acumulador
        suma=suma+estudiante

# %% [markdown]
# #LISTAS
# Son un tipo de dato  **mutable**, que permite almacenar incontable cantidad de elementos. Todos los elementos dentro de la lista, se separa con comas
#
# Sintaxis
# ...
# # Crear listas
# variable= []
# ....
#
#
# # Crear listas
# variable=

# %%
1n=5
estudiantes=[]
for i in range (1, n+1):
    estudiante=int(input)

# %%
###. count ()
dineros=250000
Compras= []
Precios=[]
while dineros>0:
Compras
  compras.append(input("Que quieres introducir a la canasta?"))
  precios.append8(int(input("Cuanto cuesta el producto: ")))
  dinero=dineros-precio

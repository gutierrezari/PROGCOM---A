# %% [markdown]
# #Estructura de selección

# %% [markdown]
# ##If-else

# %% [markdown]
# If (condición):
# Se ejecuta si la condición es falsa

# %% [markdown]
# 1 x=input("Quieres helado?")
# 2 if x.lower()0= == "si" or x.lower() ¿== "si":
# 3 print ("vamos a comer helado")
# 4  h=input("Que sabor quieres?")
# if h=="vainilla":input(f"Aqui tiene su helado de {h}")
# elif h=="chicle":print(f"aqui tiene su helado de {h}")
# else:
# 5 print ("sta bien")

# %%
x=input ("Quieres helado?")
if x.lower()0=

# %% [markdown]
# ##if/elif/else
# Se debe colocar tantas condiciones como sea necesario
#
# Sintaxis
#
# if (c1): aqui se ejecuta d
# si c1 es verdadera
# elif (c2): aqui se ejecuta si c2 es verdadera y c1 es falsa
# elif (cn): aqui se ejecuta si cn es verdadera y c1
# else: aqui se ejecuta si todas las condiciones son

# %% [markdown]
# ##match-case
# Estructura de selección, empleada para evaluar diferentes valores *CON SOLO UNA CONDICION**
#
# Sintaxis
#
# match variable
#   case "valor1": aqui se ejecuta si variable==valor1
#   case "valor2": aqui se ejecuta si variable==valorn
#   case_:ninguna de las anteriore

# %%
input ("Quieres helado?")
if x.lower()=="si" or x.lower()=="si":
  h=input ("Que sabor quieres?")
  match h:
    case "vainilla": print(f"Aqui tiene su helado de {h}")

# %%
a= "Vamos a comer helado" if x=="sí" or x== "si" "else"
# Out:
#   File "/tmp/ipykernel_3049/2646127886.py", line 1
#     a= "Vamos a comer helado" if x=="sí" or x== "si" "else"
#        ^
# SyntaxError: expected 'else' after 'if' expression

# %% [markdown]
# Sintaxis
#
# (Resultado si condicion es V)
# If condicion else (resultado si condicion es F)

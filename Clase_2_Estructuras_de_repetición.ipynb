# %% [markdown]
# <a href="https://colab.research.google.com/github/gutierrezari/PROGCOM---A/blob/main/Clase_2_Estructuras_de_repetici%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ESTRUCTURA DE REPETICION
# Estructura computacionhasta al que permite repetir una acción n cantidad de veces o hasta que se logre una condición

# %% [markdown]
# #Estructura PARA  (FOR)
# Estructura empleada para

# %% [markdown]
# Cuando se sabe cuántas veces se debe repetir una acción
#
# Sintáxis general
# ´´´´
#
# for (variable) in range (VI, VF, Paso):

# %%
"Tabla del n"
n=int(input("Que tabla de multiplicar deseas?"))
print (f"Tabla del {n}")
for i in range (1,1):
    print(f"{n}" x {1} = {n+1}] )

# %%
for i in range (1,11):
    print f (tabla del )

# %%
for x in range (1,11) : #Este controla el numero de la tabla
  for y in range(1,11): #Este controla
  print(f"{x}x{y}={x+y}")
  print()

# %%
n=int(input("Hasta qué numero de serie desea visualizar?"))
for serie in range (1,n+1):
  if serie==1: print(1,end=" ")
  elif serie%2==0: print(f"-1"/{serie}"",end-" "")
  else: print(f"+1/{serie}")

# %% [markdown]
# #   Estructura mientras (while)
# While (condicion):
#   Ejecuta el codigo
#   Modificador de la condición
#   break

# %%
#Hacer un programa que imprima los numeros pares d
par=-2
while par<=20:
  print (par)
  par+par-2 #par-par+2
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# ...

# %%
t=1
while t <-10:
    print (f"Tabla del {t}")
    while y<-10
      print(f"{t}x{y}={t*y}")
      y+1
    t+=1
    print()

# %% [markdown]
# <a href="https://colab.research.google.com/github/gutierrezari/PROGCOM---A/blob/main/Ejercicio_agenda_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio agenda
def menu():
  print("Bienvenid@ a tu agenda")
  print("Estas son tus opciones\n2.Agregar actividad\n3. Buscar actividad")
  print("4. Eliminar actividad\n5. Mostrar cantidad de actividades\n6.Ver primer actividad")
  print("7.Ver última actividad\n8.Mostrar actividades\n9.Salir\n")
opc=0
agenda=[]
while opc!=9:
  menu()#Esto llama a la función menú
  opc=int(input("Elija su opción: "))
  match opc:
    case 1:
      for x in enumerate(agenda):
        print(x)
    case 2:
      h=input("¿Qué actividad quieres agregar?: ")
      agenda.append(h)
    case 3:
      posicion=int(input("¿Qué actividades deseas buscar? "))
      print(f"La actividad buscada es: {agenda[posicion]}")
    case 4:
        for x in enumerate(agenda):
          print(x)
        print()
        posicion=int(input("¿Qué actividades deseas eliminar? "))
        print(f"La actividad eliminada es: {agenda.pop[posicion]}")
    case 5: print(f"Cantidad de actividades almacenadas: {Len(agenda)}")
    case 6: print(f"Primera actividad almacenada: {agenda[0]}")
    case 7: print(f"Última actividad almacenada: {agenda[-1]}")
    case 8:
      print("¿Qué actividad deseas reordenar")
      for x in enumerate(agenda):
        print(x)
      print()
      ind1=int(input("Ingrese el número de la primera actividad que quieres cambiar"))
      ind2=int(input("Ingrese el número de la segunda actividad que quieres cambiar"))
      if 0 <=ind1<len(agenda) and 0<=ind2<en(agenda):
        agenda[ind1],agenda[ind2]=agenda[ind2],agenda[ind1]
        print("Actividades intercambiadas de forma exitosa")
        print()
      else: print("Indices invalidos")
    case 9: break
    case _: print("Elemento no válido")
